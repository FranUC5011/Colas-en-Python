# %% [markdown]
# <a href="https://colab.research.google.com/github/FranUC5011/Colas-en-Python/blob/main/Ejercicio%2302.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

cola = deque([1150, 2848, 3058, 4890, 5890, 6875, 7899, 8888])

print(len(cola))
# Out:
# 8
