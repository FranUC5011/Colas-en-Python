# %% [markdown]
# <a href="https://colab.research.google.com/github/FranUC5011/Colas-en-Python/blob/main/Ejercicio%2301.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

cola = deque([101, 258, 780, 840, 950])

if cola:
    print(cola[0])
# Out:
# 101
