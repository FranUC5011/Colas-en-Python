# %% [markdown]
# <a href="https://colab.research.google.com/github/FranUC5011/Colas-en-Python/blob/main/Ejercicio%2304.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import deque

cola = deque([6810, 7950, 2430, 3340, 1520])

if cola:
    menor = min(cola)
    cola.appendleft(menor)

print(cola)
# Out:
# deque([1520, 6810, 7950, 2430, 3340, 1520])
